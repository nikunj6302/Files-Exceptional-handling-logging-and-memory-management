# %% [markdown]
# #Files, Exceptional handling, Logging and memory management

# %% [markdown]
# 1. What is the diffence between interpreted and compiled languanges?
#  - Interpreted languages, like Python or JavaScript, are executed line by line by an interpreter, which translates and runs each instruction as it goes. Compiled languages, like C++ or Java, are first translated entirely into machine code by a compiler before being executed.
#
# 2. What is exceptional handling in Pyhton?
#  - If there is an error in a code we can hanle that error with exceptional handling like we can get the type of error as output and the code will run after the error as it is.
#
#
# 3. What is the purpose of the finally block in exception handling?
#  - In the exceptional hanlng the final block will run always like regard less the error the code under the final block will always exceuted.
#
# 4. What is logging in Python?
#  - To get exect location of the error we can log the whole code in a directory and we will find out where is the error accur so we can work on it.
#
# 5. What is the signigicance of the __del__ method in Python?
#  - the __del__ method is used to delete any functions or vatiable from the code.
#
# 6. What is the difference between import and from ... import in Python?
#  - This statement imports the entire module. To access items within the module, you need to use the module name as a prefix. And in from ...  import we can just import only the item we need from the module, insteed of importing whole module.
#
# 7. How can you handle multiple exceptions in Python?
#  - We can handle the multiple exceptions by try and exept specific errors like ValueError,ZeroDivisionError one by one.
#
# 8. what is the purpose of the with statement when handling files in Python?
#  - We can operate any methon as a variable like in code we can write with ..... as x . so the whole oparation will store as x.
#
# 9. What is the difference between multithreading and multiprocessing?
#  - Multithreading will run the code concurrently on multithread in a single processor, while in multiprocesseor run the code paraller in multiple processor.
#
# 10. What are the advantages of using logging in a program?
#  - We can logg and note down everything regarding the code that we are working on and we if there is an error we can find it and manage it by looking in the logg we made.
#
# 11. What is memory management in Python?
#  - Python memory management is the process of allocating and dealing with memory so that your programs can run efficiently.
#
# 12. What is the basic steps involved in exception handling in Python?
#  - basic steps are use try adn then write the code and if the error will occur do except type of error as e and print the error as e.
#
# 13. Why is memory management important in Python?
#  - Memory management is crucial in Python for ensuring efficient resource utilization and preventing issues like memory leaks.
#
# 14. What is the role of try and except in exception handling?
#  - try is for try the code if it is okay run it and if it through an error then exept will say print the type of error so we can solve it.
#
# 15. How does Python's garbage collection system work?
#  - Python uses a hybrid garbage collection system consisting of reference counting and generational garbage collection. This system automatically manages memory, freeing up space occupied by objects that are no longer in use
#
# 16. What is the purpose of the else block in exception handling?
#  - Else block in exeptional handling says that if the code in try will through an error then only run the else code.
#
# 17. What are the common logging levels in Python?
#  - The common logging levels are Info, Watning, Error, Debug, Critical, Shutdown.
#
# 18. What is difference between os.fork() and multiprocessing in Python?
#  - The os.fork() system call and the multiprocessing module in Python both enable the creation of new processes, but they differ significantly in their approach, portability, and use cases
#
# 19. What is the importance of closing a file in Python?
#  - if we open a file in a writing mode, what we have write does not save in file untill we do not close the file.
#
# 20. What is the difference between file.read() and file.readline() in Python?
#  - file.read is for read the whole file while the file.readline is use for read any specific line.
#
# 21. What is the logging module in Python used for?
#  - for logging we use import logging.
#
# 22. What is the os module in Python used for in the file handling?
#  - for file handling we use import os and import sys modules.
#
# 23. What are the challenges associated with memory management in Python?
#  - Challenges associated with memory management in Python include:Memory Leaks, Memory Bloat, Garbage Collection Overhead, Fragmentation, Limited Control, Multithreading and Multiprocessing, Reference Counting Overhead:
#
# 24. How do you raise a exception manually in Python?
#  - to raise a exeption maually we need to define an constum class of an error which is child class on Exception and just give the condition where need to raise the error.
#
# 25. Why is it important to use multithreading in certain applications?
#  - to run the code more effectivly and faster we can use multithreading.

# %% [markdown]
# #Practical Assingment

# %%
# Ans. 1
with open("example.txt",'w') as f:
  f.write("this is my first line \n")
  f.write("this is my second line \n")
  f.write("this is my third line \n")
  f.write("this is my fourth line \n")

# %%
#Ans. 2
with open("example.txt",'r') as f:
  for i in f:
    print(i)
# Out:
# this is my first line
#
# this is my second line
#
# this is my third line
#
# this is my fourth line

# %%
# Ans. 3

try:
  with open("unknownfile.txt",'r') as unknown:
    for i in unknown:
      print(i)

except Exception as e:
  print(e)
  with open("unknownfile.txt",'w') as unknown:
    unknown.write("this is my first line \n")
  print("new file created")
# Out:
# [Errno 2] No such file or directory: 'unknownfile.txt'
# new file created

# %%
#Ans. 4

with open("example.txt",'r') as f:
  with open ("example2.txt",'w') as f2:
    for i in f:
      f2.write(i)

# %%
#Ans. 5
try:
  10/0
except ZeroDivisionError as e:
  print(e)
# Out:
# division by zero

# %%
#Ans. 6
import logging
logging.basicConfig(filename="errors.log",level=logging.ERROR)
try:
  10/0
except ZeroDivisionError as e:
  logging.error(e)
# Out:
# ERROR:root:division by zero

# %%
#Ans. 7

# %%
#Ans. 8
try:
  with open("example3.txt",'w') as file:
    file.read

except Exception as e:
  print(e)
  with open("example3.txt",'w') as unknown:
    file.write("this is my first line \n")
  print("now file is created")

# %%
#Ans. 9

l = []
with open("example.txt", 'r') as f3:
  for i in f3:
    l.append(i)
print(l)
# Out:
# ['this is my first line \n', 'this is my second line \n', 'this is my third line \n', 'this is my fourth line \n']

# %%
#Ans. 10
with open("example.txt", 'a') as f4:
  f4.write("this is my fifth line \n")

# %%
#Ans. 11

dics = {"name":"nikunj", "age":"23"}

try:
  dics["name"]
  dics["study"]

except Exception as e:
  print(e ,"does not found")
# Out:
# 'study' does not found

# %%
# Ans. 12
try:
  10/"h"
except SyntaxError as e:
  print(e, "syntax error")

except TypeError as t:
  print(t, "type error")

except ValueError as v:
  print(v, "value error")

except ZeroDivisionError as z:
  print(z, "zero division error")
# Out:
# unsupported operand type(s) for /: 'int' and 'str' type error

# %%
#Ans. 13
try:
  with open("unknownfile.txt",'r') as unknown:
    for i in unknown:
      print(i)

except Exception as e:
  print(e)
  with open("unknownfile.txt",'w') as unknown:
    unknown.write("this is my first line \n")
  print("new file created")
# Out:
# this is my first line

# %%
# Ans. 14

# %%
# Ans 15

file = open("empty.txt",'w')
file.close()

try:
  with open ("empty.txt",'r') as empty:
    for i in empty:
      print(i)
except Exception as e:
  print(e)

# %%
#Ans. 16
